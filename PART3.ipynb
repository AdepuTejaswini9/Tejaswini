# %% [markdown]
# <a href="https://colab.research.google.com/github/AdepuTejaswini9/Tejaswini/blob/main/PART3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("/content/Tejaswini.txt")

# %%
df1
# Out:
# Empty DataFrame
# Columns: [Tejaswini]
# Index: []

# %%
data2 = pd.read_csv("/content/Info.csv")

# %%
data2
# Out:
#         Name     Roll.no
# 0  Tejaswini  2303A51423
# 1    Keerthi  2303A51427

# %%
data3 = pd.read_excel("/content/Batch.xlsx")

# %%
data3
# Out:
#         Name Batch
# 0  Tejaswini   CSE
# 1    Keerthi   CSE
# 2     Sindhu  AIML
